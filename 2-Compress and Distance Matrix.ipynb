# %% [markdown]
# # Compress and Distance Matrix

# %%
data_dir = './data/genomes'
combined_dir = f'{data_dir}/combined'

overwrite = False

# %%
accessions = [
    'CM054508.1',      # Pan paniscus (Pygmy chimpanzee)
    'NC_001321.1',     # Balaenoptera physalus (Finback whale)
    'NC_001325.1',     # Phoca vitulina (Harbor seal)
    'NC_001601.1',     # Balaenoptera musculus (Blue whale),
    'NC_001602.1',     # Halichoerus grypus (Gray seal)
    'NC_001610.1',     # Didelphis virginiana (Opossum)
    'NC_001640.1',     # Equus caballus (Horse)
    'NC_001643.1',     # Pan troglodytes (Chimpanzee)
    'NC_001645.1',     # Gorilla (Gorilla)
    'NC_001700.1',     # Felis catus (Cat)
    'NC_001794.1',     # Macropus robustus (Wallaroo)
    'NC_001808.1',     # Ceratotherium simum (White rhinoceros)
    'NC_002083.1',     # Pongo abelii (Orangutan)
    'NC_010339.1',     # Mus musculus musculus (House mouse)
    'NC_012374.1',     # Rattus rattus (Rat)
    'OK135155.1',      # Bos taurus (Cow)
    'OM287160.1',      # Nomascus siki (Hylobatidae/Gibbon)
    'OM864526.1',      # Gallus gallus (Chicken)
    'OP605624.1'       # Homo sapiens (Human)
]

count = len(accessions)

# %%
common_names = [
    'Pygmy chimpanzee',
    'Finback whale',
    'Harbor seal',
    'Blue whale',
    'Gray seal',
    'Opossum',
    'Horse',
    'Chimpanzee',
    'Gorilla',
    'Cat',
    'Wallaroo',
    'White rhinoceros',
    'Orangutan',
    'House mouse',
    'Rat',
    'Cow',
    'Gibbon',
    'Chicken',
    'Human'
]

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Compress

# %%
# accessions, count, data_dir, commbined_dir, fasta extension = fna
def compress_files(compressor, verbose=False):
    compressed_files = {}

    for accession in accessions:
        fasta = f'{data_dir}/{accession}.fna'
        if verbose:
            print(f'Compressing {accession}')
        compressed_file = compressor(fasta)
        compressed_files[accession] = compressed_file

    for i in range(count):
        for j in range(i+1, count):
            combined_fasta = f'{accessions[i]}+{accessions[j]}' 
            fasta = f'{combined_dir}/{combined_fasta}.fna'
            if verbose:
                print(f'Compressing {accessions[i]} and {accessions[j]}')
            compressed_file = compressor(fasta)
            compressed_files[combined_fasta] = compressed_file
    
    return compressed_files

# %% [markdown]
# ### Distance Matrix Creation

# %%
import os

def distance(a, b, ab):
    """Calculates the distance measure between a and b.
    :param a: compressed a
    :param b: compressed b
    :param ab: compressed ab-merge
    :return: distance measure
    """
    a_size = os.stat(a).st_size   # file size of a
    b_size = os.stat(b).st_size   # file size of b
    ab_size = os.stat(ab).st_size # file size of ab
    
    return 1 - (((a_size + b_size) - ab_size) / ab_size)

# %%
# accesssions
from Bio.Phylo.TreeConstruction import DistanceMatrix
import os

def create_distance_matrix(names, compressed_files, distance=distance, verbose=False):
    distance_matrix = DistanceMatrix(names)
    count = len(accessions)
    for i in range(count):
        a = accessions[i]
        az = compressed_files[a]

        if not os.path.exists(az):
            print(f'ERROR: {az} not exists')

        distances = []
        for j in range(count):
            if i == j:
                distances.append(0)
                continue

            b = accessions[j]
            bz = compressed_files[b]

            if not os.path.exists(bz):
                print(f'ERROR: {bz} not exists')

            combined = f'{b}+{a}'
            if i < j:
                combined = f'{a}+{b}'
            abz = compressed_files[combined]

            if not os.path.exists(abz):
                print(f'ERROR: {abz} not exists')        

            d = distance(az, bz, abz)

            distances.append(d)

            if verbose:
                print(f'distance({a}, {b}) = {d}')

        distance_matrix[i] = distances

    return distance_matrix

# %%
import pandas as pd

def to_df(distane_matrix, names):
    return pd.DataFrame(list(distane_matrix), index=names, columns=names)

# %% [markdown]
# ---

# %% [markdown]
# ## GenCompress

# %%
compressed_dir = './data/gencompress'

def gencompress(fasta, overwrite=False):
    compressed_file = f'{compressed_dir}/{os.path.split(fasta)[-1]}.GEN'
    return compressed_file

# %%
gencompress_compressed_files = compress_files(gencompress)

# %%
gencompress_distance_matrix= create_distance_matrix(common_names, gencompress_compressed_files)

# %%
df = to_df(gencompress_distance_matrix, common_names)
df
# Out:
#                   Pygmy chimpanzee  Finback whale  Harbor seal  Blue whale
# Pygmy chimpanzee          0.000000       0.989427     0.998172    0.996187  \
# Finback whale             0.989427       0.000000     0.997704    0.818418
# Harbor seal               0.998172       0.997704     0.000000    1.001831
# Blue whale                0.996187       0.818418     1.001831    0.000000
# Gray seal                 0.997023       0.994813     0.668786    0.989912
# Opossum                   0.990460       0.996326     0.994067    0.999542
# Horse                     0.995159       1.008003     0.998970    1.001728
# Chimpanzee                0.681034       0.989994     0.994718    0.993617
# Gorilla                   0.871585       0.989820     0.995732    0.995808
# Cat                       0.995434       0.997138     0.994994    0.997709
# Wallaroo                  0.992908       0.992991     0.996138    0.990544
# White rhinoceros          1.000573       1.002869     1.003979    1.000691
# Orangutan                 0.976207       0.994888     0.994700    0.996633
# House mouse               0.996157       0.999067     0.995472    0.996016
# Rat                       0.995697       0.992970     0.997224    0.990475
# Cow                       0.997108       1.000579     0.991307    0.996157
# Gibbon                    0.981410       0.995482     0.993671    0.995011
# Chicken                   0.995069       0.994352     0.993824    0.991435
# Human                     0.869599       0.996076     0.994613    0.999885
#
#                   Gray seal   Opossum     Horse  Chimpanzee   Gorilla
# Pygmy chimpanzee   0.997023  0.990460  0.995159    0.681034  0.871585  \
# Finback whale      0.994813  0.996326  1.008003    0.989994  0.989820
# Harbor seal        0.668786  0.994067  0.998970    0.994718  0.995732
# Blue whale         0.989912  0.999542  1.001728    0.993617  0.995808
# Gray seal          0.000000  0.998977  0.997821    1.000457  0.996885
# Opossum            0.998977  0.000000  0.990786    0.987877  0.990739
# Horse              0.997821  0.990786  0.000000    0.994336  0.995589
# Chimpanzee         1.000457  0.987877  0.994336    0.000000  0.895073
# Gorilla            0.996885  0.990739  0.995589    0.895073  0.000000
# Cat                0.988653  0.998075  0.993696    0.998974  0.994128
# Wallaroo           0.995562  0.987297  0.995655    0.990696  0.992158
# White rhinoceros   0.999085  0.995535  0.987205    0.996082  0.996176
# Orangutan          0.997123  0.991691  1.001612    0.980371  0.979536
# House mouse       0.992872
# Rat               0.993120
# Cow               1.000922
# Gibbon            0.984970
# Chicken           0.995530
# Human             0.000000

# %%
df.to_csv(f'{compressed_dir}/gencompress_distance-matrix.csv')

# %% [markdown]
# ## bzip3

# %%
import os

compressed_dir = './data/bzip3'

if overwrite or not os.path.exists(compressed_dir):
    # !rm -Rf {compressed_dir}
    # !mkdir -p {compressed_dir}

def bzip3(fasta, overwrite=overwrite):
    compressed = f'{fasta}.bz3'
    compressed_file = f'{compressed_dir}/{os.path.split(fasta)[-1]}.bz3'
    if overwrite or not os.path.exists(compressed_file):
        # !bzip3 {fasta}
        # !mv {compressed} {compressed_dir}
    return compressed_file

# %%
bzip3_compressed_files = compress_files(bzip3)

# %%
bzip3_distance_matrix= create_distance_matrix(common_names, bzip3_compressed_files)

# %%
df = to_df(bzip3_distance_matrix, common_names)
df
# Out:
#                   Pygmy chimpanzee  Finback whale  Harbor seal  Blue whale
# Pygmy chimpanzee          0.000000       0.981426     0.982196    0.981998  \
# Finback whale             0.981426       0.000000     0.981740    0.945171
# Harbor seal               0.982196       0.981740     0.000000    0.981132
# Blue whale                0.981998       0.945171     0.981132    0.000000
# Gray seal                 0.982883       0.981843     0.923738    0.982060
# Opossum                   0.986832       0.985821     0.986078    0.986041
# Horse                     0.981516       0.980342     0.979246    0.979133
# Chimpanzee                0.932654       0.982550     0.982373    0.982295
# Gorilla                   0.960465       0.983063     0.983351    0.982093
# Cat                       0.982981       0.981362     0.976885    0.981577
# Wallaroo                  0.983646       0.982147     0.982440    0.981659
# White rhinoceros          0.981967       0.980321     0.980048    0.980420
# Orangutan                 0.974860       0.983677     0.983137    0.982829
# House mouse               0.983296       0.981882     0.982184    0.981383
# Rat                       0.982255       0.981912     0.981977    0.981174
# Cow                       0.982560       0.980073     0.980865    0.979812
# Gibbon                    0.975405       0.983366     0.983884    0.982757
# Chicken                   0.983556       0.984987     0.985020    0.984736
# Human                     0.962946       0.982827     0.983232    0.982809
#
#                   Gray seal   Opossum     Horse  Chimpanzee   Gorilla
# Pygmy chimpanzee   0.982883  0.986832  0.981516    0.932654  0.960465  \
# Finback whale      0.981843  0.985821  0.980342    0.982550  0.983063
# Harbor seal        0.923738  0.986078  0.979246    0.982373  0.983351
# Blue whale         0.982060  0.986041  0.979133    0.982295  0.982093
# Gray seal          0.000000  0.987108  0.978522    0.982124  0.983572
# Opossum            0.987108  0.000000  0.983674    0.987371  0.988130
# Horse              0.978522  0.983674  0.000000    0.980865  0.981725
# Chimpanzee         0.982124  0.987371  0.980865    0.000000  0.963051
# Gorilla            0.983572  0.988130  0.981725    0.963051  0.000000
# Cat                0.977803  0.986261  0.979465    0.983625  0.984017
# Wallaroo           0.982426  0.980201  0.978956    0.983593  0.983752
# White rhinoceros   0.980503  0.984125  0.973279    0.982735  0.982417
# Orangutan          0.983593  0.989192  0.981867    0.975138  0.974175
# House mouse        0.982407  0.980969  0.979702    0.983480  0.983641
# Rat                0.983027  0.983488  0.980810    0.982912  0.983429
# Human             0.000000

# %%
df.to_csv(f'{compressed_dir}/bzip3_distance-matrix.csv')

# %% [markdown]
# ## fastGzip: gzip -1 -n

# %%
import os

compressed_dir = './data/fastgzip'

if overwrite or not os.path.exists(compressed_dir):
    # !rm -Rf {compressed_dir}
    # !mkdir -p {compressed_dir}

def fast_gzip(fasta, overwrite=overwrite):
    compressed = f'{fasta}.gz'
    compressed_file = f'{compressed_dir}/{os.path.split(fasta)[-1]}.gz'
    if overwrite or not os.path.exists(compressed_file):
        # !gzip -1 -n {fasta}
        # !cp {compressed} {compressed_dir}
        # !gunzip {compressed}
    return compressed_file

# %%
fastgzip_compressed_files = compress_files(fast_gzip)

# %%
fastgzip_distance_matrix = create_distance_matrix(common_names, fastgzip_compressed_files)

# %%
df = to_df(fastgzip_distance_matrix, common_names)
df
# Out:
#                   Pygmy chimpanzee  Finback whale  Harbor seal  Blue whale
# Pygmy chimpanzee          0.000000       0.991633     0.991694    0.992041  \
# Finback whale             0.991633       0.000000     0.988809    0.985573
# Harbor seal               0.991694       0.988809     0.000000    0.989298
# Blue whale                0.992041       0.985573     0.989298    0.000000
# Gray seal                 0.993194       0.991605     0.984400    0.990986
# Opossum                   0.991810       0.989108     0.990119    0.990706
# Horse                     0.990798       0.987799     0.988659    0.988808
# Chimpanzee                0.990560       0.988770     0.987998    0.988830
# Gorilla                   0.989996       0.990004     0.988963    0.990500
# Cat                       0.991048       0.989701     0.990960    0.990361
# Wallaroo                  0.991816       0.989031     0.990295    0.991650
# White rhinoceros          0.989709       0.991173     0.988767    0.989950
# Orangutan                 0.989850       0.988565     0.988049    0.988019
# House mouse               0.991073       0.989618     0.989695    0.988463
# Rat                       0.990816       0.989445     0.989523    0.990028
# Cow                       0.989320       0.990100     0.989317    0.987479
# Gibbon                    0.989760       0.989508     0.987785    0.988705
# Chicken                   0.990344       0.989586     0.989747    0.989819
# Human                     0.989198       0.989888     0.989195    0.990123
#
#                   Gray seal   Opossum     Horse  Chimpanzee   Gorilla
# Pygmy chimpanzee   0.993194  0.991810  0.990798    0.990560  0.989996  \
# Finback whale      0.991605  0.989108  0.987799    0.988770  0.990004
# Harbor seal        0.984400  0.990119  0.988659    0.987998  0.988963
# Blue whale         0.990986  0.990706  0.988808    0.988830  0.990500
# Gray seal          0.000000  0.991361  0.990425    0.988391  0.989189
# Opossum            0.991361  0.000000  0.988362    0.990339  0.990031
# Horse              0.990425  0.988362  0.000000    0.989135  0.988558
# Chimpanzee         0.988391  0.990339  0.989135    0.000000  0.989957
# Gorilla            0.989189  0.990031  0.988558    0.989957  0.000000
# Cat                0.990510  0.990068  0.990061    0.991183  0.991731
# Wallaroo           0.990860  0.989659  0.990498    0.989583  0.990976
# White rhinoceros   0.990102  0.991441  0.988534    0.990781  0.990731
# Orangutan          0.987669  0.988949  0.988931    0.987404  0.987422
# House mouse        0.989751  0.991873  0.989466    0.991039  0.989863
# Rat                0.990440  0.991361  0.991452    0.991727  0.990556
# Cow                0.988166  0.990637  0.988655    0.988160  0.988269
df.to_csv(f'{compressed_dir}/fastgzip_distance-matrix.csv')

# %% [markdown]
# ## genozip: genozip --best --multiseq --quiet --no-tip --force

# %%
import os

compressed_dir = './data/genozip'

if overwrite or not os.path.exists(compressed_dir):
    # !rm -Rf {compressed_dir}
    # !mkdir -p {compressed_dir}


def genozip(fasta, overwrite=overwrite):
    compressed = f'{fasta}.genozip'
    compressed_file = f'{compressed_dir}/{os.path.split(fasta)[-1]}.genozip'
    if overwrite or not os.path.exists(compressed_file):
        # !genozip --best --multiseq --quiet --no-tip --force {fasta}
        # !mv {compressed} {compressed_dir}
    return compressed_file

# %%
genozip_compressed_files = compress_files(genozip)

# %%
genozip_distance_matrix = create_distance_matrix(common_names, genozip_compressed_files)

# %%
df = to_df(genozip_distance_matrix, common_names)
df
# Out:
#                   Pygmy chimpanzee  Finback whale  Harbor seal  Blue whale
# Pygmy chimpanzee          0.000000       0.753149     0.756864    0.752919  \
# Finback whale             0.753149       0.000000     0.677599    0.421333
# Harbor seal               0.756864       0.677599     0.000000    0.663407
# Blue whale                0.752919       0.421333     0.663407    0.000000
# Gray seal                 0.756619       0.688705     0.349059    0.667741
# Opossum                   0.758305       0.705579     0.709343    0.705949
# Horse                     0.760064       0.668686     0.642839    0.654111
# Chimpanzee                0.464438       0.702451     0.706264    0.701457
# Gorilla                   0.574019       0.702808     0.707564    0.701600
# Cat                       0.757015       0.693488     0.617892    0.668588
# Wallaroo                  0.756508       0.704260     0.708854    0.703066
# White rhinoceros          0.756287       0.659172     0.627561    0.638938
# Orangutan                 0.643937       0.703539     0.707033    0.702755
# House mouse               0.748360       0.739401     0.742859    0.731260
# Rat                       0.754316       0.701572     0.706669    0.700994
# Cow                       0.731193       0.698789     0.699732    0.686271
# Gibbon                    0.631481       0.746381     0.752294    0.745651
# Chicken                   0.732098       0.746298     0.749282    0.746651
# Human                     0.534470       0.750834     0.753554    0.750601
#
#                   Gray seal   Opossum     Horse  Chimpanzee   Gorilla
# Pygmy chimpanzee   0.756619  0.758305  0.760064    0.464438  0.574019  \
# Finback whale      0.688705  0.705579  0.668686    0.702451  0.702808
# Harbor seal        0.349059  0.709343  0.642839    0.706264  0.707564
# Blue whale         0.667741  0.705949  0.654111    0.701457  0.701600
# Gray seal          0.000000  0.708965  0.643661    0.705986  0.706974
# Opossum            0.708965  0.000000  0.711234    0.707266  0.706802
# Horse              0.643661  0.711234  0.000000    0.708879  0.708004
# Chimpanzee         0.705986  0.707266  0.708879    0.000000  0.500796
# Gorilla            0.706974  0.706802  0.708004    0.500796  0.000000
# Cat                0.617325  0.708410  0.640285    0.706470  0.706523
# Wallaroo           0.708167  0.680072  0.708367    0.704910  0.705897
# White rhinoceros   0.627582  0.708017  0.585496    0.703882  0.705285
# Orangutan          0.706548  0.707415  0.709031    0.576237  0.575555
# House mouse        0.741915  0.743231  0.746402    0.741555  0.742022
# Rat                0.706806  0.704016  0.707524    0.701813  0.704388
# Cow                0.699025  0.748687  0.691600    0.746538  0.746030
# Gibbon             0.749610  0.751814  0.751954    0.643980  0.649342
# %% [markdown]
# ## fastgenozip: genozip --fast --multiseq --quiet --no-tip --force

# %%
import os

compressed_dir = './data/fastgenozip'

if overwrite or not os.path.exists(compressed_dir):
    # !rm -Rf {compressed_dir}
    # !mkdir -p {compressed_dir}


def fastgenozip(fasta, overwrite=overwrite):
    compressed = f'{fasta}.genozip'
    compressed_file = f'{compressed_dir}/{os.path.split(fasta)[-1]}.genozip'
    if overwrite or not os.path.exists(compressed_file):
        # !genozip --fast --multiseq --quiet --no-tip --force {fasta}
        # !mv {compressed} {compressed_dir}
    return compressed_file

# %%
fastgenozip_compressed_files = compress_files(fastgenozip)

# %%
fastgenozip_distance_matrix = create_distance_matrix(common_names, fastgenozip_compressed_files)

# %%
df = to_df(fastgenozip_distance_matrix, common_names)
df
# Out:
#                   Pygmy chimpanzee  Finback whale  Harbor seal  Blue whale
# Pygmy chimpanzee          0.000000       0.759447     0.762615    0.758673  \
# Finback whale             0.759447       0.000000     0.707522    0.426530
# Harbor seal               0.762615       0.707522     0.000000    0.707808
# Blue whale                0.758673       0.426530     0.707808    0.000000
# Gray seal                 0.763116       0.707465     0.353167    0.708370
# Opossum                   0.764120       0.708527     0.712362    0.708607
# Horse                     0.769271       0.705372     0.717513    0.705556
# Chimpanzee                0.474367       0.704315     0.709143    0.704395
# Gorilla                   0.759613       0.715006     0.709265    0.705341
# Cat                       0.762387       0.707362     0.710479    0.708058
# Wallaroo                  0.756202       0.700752     0.703739    0.700624
# White rhinoceros          0.757240       0.702469     0.704106    0.701615
# Orangutan                 0.758463       0.705556     0.708828    0.704175
# House mouse               0.754926       0.745313     0.750058    0.735512
# Rat                       0.759063       0.712460     0.707636    0.705045
# Cow                       0.734805       0.749374     0.760613    0.748962
# Gibbon                    0.736531       0.751345     0.752939    0.759454
# Chicken                   0.737808       0.753047     0.755386    0.751962
# Human                     0.537605       0.756308     0.767525    0.756863
#
#                   Gray seal   Opossum     Horse  Chimpanzee   Gorilla
# Pygmy chimpanzee   0.763116  0.764120  0.769271    0.474367  0.759613  \
# Finback whale      0.707465  0.708527  0.705372    0.704315  0.715006
# Harbor seal        0.353167  0.712362  0.717513    0.709143  0.709265
# Blue whale         0.708370  0.708607  0.705556    0.704395  0.705341
# Gray seal          0.000000  0.710570  0.709198    0.709600  0.709209
# Opossum            0.710570  0.000000  0.709436    0.711690  0.721120
# Horse              0.709198  0.709436  0.000000    0.715752  0.706502
# Chimpanzee         0.709600  0.711690  0.715752    0.000000  0.704820
# Gorilla            0.709209  0.721120  0.706502    0.704820  0.000000
# Cat                0.709507  0.720872  0.718332    0.707645  0.708277
# Wallaroo           0.704402  0.703907  0.712254    0.700527  0.700833
# White rhinoceros   0.703639  0.704892  0.702987    0.701310  0.710501
# Orangutan          0.706916  0.722591  0.706378    0.704386  0.704182
# House mouse        0.748259  0.747321  0.746069    0.748366  0.757035
# Rat                0.707889  0.705111  0.706522    0.704942  0.705997
# Cow                0.753255  0.753786  0.750702    0.750762  0.749628
# Gibbon             0.753267  0.766511  0.751108    0.751752  0.751016
